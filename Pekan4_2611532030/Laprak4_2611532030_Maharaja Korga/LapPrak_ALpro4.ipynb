# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **"Struktur Percabangan pada Python"**
#
# **Disusun Oleh :**
#
# **Maharaja Korga**
#
# **2611532030**
#
# **Dosen Pengampu:**
#
# **Dr. Ir WAHYUDI, ST., MT.**
#
# **Asisten Praktikum:**
#
# **Rifky Yuliandra**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur kehadirat Tuhan Yang Maha Esa atas segala rahmat dan karunia-Nya sehingga laporan praktikum Algoritma dan Pemrograman dengan judul "Struktur Percabangan pada Python (if, if-else, if-elif-else, multi-if, match-case)" ini dapat diselesaikan dengan baik dan tepat waktu.
#
# Laporan ini disusun untuk memenuhi tugas praktikum serta memperdalam pemahaman mengenai konsep dasar pemrograman Python, khususnya pada penerapan fungsi masukan/keluaran, operator logika, serta struktur kontrol percabangan untuk pengambilan keputusan.
#
# Penyusun menyadari bahwa laporan ini masih memiliki kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi kesempurnaan laporan ini di masa mendatang. Semoga laporan ini dapat memberikan manfaat bagi pembaca.
#
# Padang, September 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Seiring dengan perkembangan teknologi informasi yang pesat, penggunaan sistem terkomputerisasi dalam mengambil keputusan berbasis logika menjadi dasar utama pengembangan perangkat lunak. Pemrograman komputer tidak hanya mengeksekusi perintah secara berurutan (sekuensial), tetapi juga harus mampu memilih jalur eksekusi tertentu berdasarkan kondisi atau kriteria yang diberikan. Alur pengambilan keputusan ini dikenal dengan istilah struktur percabangan atau pengondisian (conditional statement).
#
# Dalam pemrograman Python, struktur percabangan diimplementasikan melalui berbagai bentuk, seperti pernyataan `if`, `if-else`, `if-elif-else`, `multi-if`, dan `match-case`. Masing-masing struktur memiliki karakteristik dan kegunaan tersendiri sesuai dengan kompleksitas logika yang dihadapi, mulai dari pengujian tunggal, banyak pilihan saling lepas (mutually exclusive), pengondisian majemuk beruntun, hingga pemetaan pola nilai tertentu secara efisien.
#
# Oleh karena itu, praktikum ini dilaksanakan untuk merancang, mengimplementasikan, dan menganalisis penggunaan berbagai bentuk struktur percabangan pada Python. Praktikum ini melatih pemahaman mendalam mengenai sintaks dasar, pemrosesan variabel masukan dari pengguna (input), penggunaan operator perbandingan dan logika, serta alur pengondisian dalam menyelesaikan masalah secara tepat dan efisien.
# ## 1.2 Tujuan
# 1. Memahami penggunaan fungsi masukan `(input())` dan keluaran `(print())` pada bahasa pemrograman Python.
# 2. Memahami sintaks dan mekanisme kerja berbagai jenis struktur percabangan (`if`, `if-else`, `if-elif-else`, `multi-if`, dan `match-case`).
# 3. Menerapkan operator perbandingan dan operator logika dalam membentuk kondisi percabangan.
# 4. Menganalisis perbedaan alur eksekusi antara struktur pengondisian bersyarat tunggal, beruntun, bersarang, dan independen.
#
# ## 1.3 Manfaat
# 1. Mampu merancang program berbasis Python yang dapat mengambil keputusan secara otomatis berdasarkan kriteria input tertentu.
# 2. Memperdalam kemampuan pemecahan masalah (problem-solving) dan logika pemrograman dalam menghadapi berbagai variasi skenario kasus nyata.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Struktur kontrol percabangan memungkinkan program menentukan eksekusi blok kode berdasarkan evaluasi kondisi boolean (`True` atau `False`). Berikut adalah konsep-konsep dasar yang digunakan pada praktikum ini:
#
# 1. Fungsi Masukan dan Konversi Tipe Data (Casting)
# Fungsi `input()` digunakan untuk mengambil masukan dari pengguna secara interaktif. Nilai kembalian default dari `input()` adalah berupa teks (`string`). Untuk melakukan perhitungan aritmatika atau evaluasi angka, data harus dikonversi terlebih dahulu menggunakan fungsi casting seperti `int()` atau `float()`.
# 2. Percabangan Tunggal (`if`)
# Struktur `if` digunakan ketika program hanya perlu mengeksekusi suatu blok kode jika kondisi bernilai `True`. Apabila kondisi bernilai `False`, maka blok kode di dalamnya dilewati dan program melanjutkan ke baris berikutnya.
# 3. Percabangan Dua Kondisi (`if-else`)
# Struktur `if-else` menyediakan dua jalur eksekusi. Blok `if` dijalankan jika kondisi bernilai `True`, sedangkan blok `else` dijalankan apabila kondisi bernilai `False`.
# 4. Percabangan Majemuk Saling Lepas (`if-elif-else`)
# Struktur `if-elif-else` digunakan untuk mengevaluasi beberapa kondisi secara berurutan. Evaluasi dimulai dari kondisi pertama; jika bernilai `True`, blok kode tersebut dieksekusi dan sisa kondisi lainnya diabaikan. Jika seluruh kondisi `if` dan `elif` bernilai `False`, maka blok `else` secara otomatis dijalankan.
# 5. Percabangan Independen (`Multi-IF`)
# Struktur `Multi-IF` terdiri dari beberapa pernyataan `if` yang ditulis secara terpisah satu sama lain. Setiap pernyataan `if` dievaluasi secara mandiri tanpa tergantung pada hasil dari pernyataan `if`  sebelumnya, sehingga memungkinkan beberapa kondisi terpenuhi secara bersamaan (dapat diakumulasi).
# 6. Percabangan Cocok-Pola (`match-case`)
# Fitur `match-case` (diperkenalkan pada Python 3.10+) bekerja mirip dengan struktur switch-case pada bahasa pemrograman lain. Fitur ini mencocokkan nilai variabel dengan beberapa `case` yang tersedia, membuat kode lebih rapi dan efisien dalam kasus seleksi nilai konstan/spesifik.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "if1_2611532030"

# %%
# Buat file dengan nama if1_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit terakhir nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

ipk_2030 = float(input("Input IPK anda = "))

if ipk_2030 > 2.75:
    print("Anda Lulus Sangat Memuaskan dengan IPK " + str(ipk_2030))

print("Program Selesai")

# %% [markdown]
# <div align="center">
# <img src="images/Output If1.png" width="500"><br>
# <em>Gambar 2.1 : Output If1</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Program meminta input numerik dari pengguna dengan `input()`, lalu dikonversi menjadi bilangan desimal menggunakan `float()` dan disimpan pada variabel `ipk_2030`.
# 2. Struktur `if` mengevaluasi kondisi apakah `ipk_2030 > 2.75`.
# 3. Jika kondisi bernilai `True`, program akan mencetak ucapan kelulusan beserta nilai IPK. Jika bernilai `False`, bagian ini dilewati dan program langsung mengeksekusi perintah mencetak "Program Selesai".

# %% [markdown]
# ### 2.2.2 Program "if2_2611532030"

# %%
# Buat file dengan nama if2_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit terakhir nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

ipk_2030 = float(input("Input IPK Anda = "))

if ipk_2030 > 2.75:
    print("Anda Lulus Samgat Memuaskan dengan IPK " + str(ipk_2030))
else:
    print("Anda Tidak Lulus")
print("Program Selesai")

# %% [markdown]
# <div align="center">
# <img src="images/Output If2.png" width="500"><br>
# <em>Gambar 2.2 : Output If2</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Program mengonversi input dari pengguna menjadi tipe `float` dan menyimpannya pada variabel `ipk_2030`.
# 2. Evaluasi kondisi `ipk_2030 > 2.75` menentukan alur eksekusi: jika bernilai `True`, blok `if` dijalankan.
# 3. Jika kondisi bernilai `False` (IPK kurang dari atau sama dengan 2.75), maka blok `else` akan dijalankan dan mencetak "Anda Tidak Lulus".

# %% [markdown]
# ### 2.2.3 Program "If_elif_else1_2611532030"

# %%
# Buat file dengan nama if_elif_else1_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit terakhir nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

umur_2030 = int(input("Input umur anda: "))
sim_2030 = input("Apakah anda sudah punya SIM C (y/t): ")[0]

if umur_2030 >= 17 and sim_2030 == 'y':
    print("Anda sudah dewasa dan boleh bawa motor")
elif umur_2030 >= 17 and sim_2030 != 'y':
    print("Anda sudah dewasa tetapi tidak boleh bawa motor")
elif umur_2030 < 17 and sim_2030 == 'y':
        print("Anda belum cukup umur punya SIM")
else:
     print("Anda belum cukup umur dan tidak boleh bawa motor")
print("Program Selesai")

# %% [markdown]
# <div align="center">
# <img src="images/Output If_elif_else1.png" width="500"><br>
# <em>Gambar 2.3 : Output If_elif_else1</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Input umur dikonversi ke tipe bilangan bulat (`int`) pada `umur_2030`, sedangkan input SIM diambil karakter pertamanya menggunakan pembagian indeks `[0]` pada `sim_2030`.
# 2. Pengondisian mengevaluasi dua ekspresi sekaligus menggunakan operator logika `and`.
# 3. Struktur `if-elif-else` akan memeriksa satu per satu kondisi dari atas ke bawah hingga menemukan kondisi yang bernilai `True`, kemudian mengabaikan sisa blok lainnya.

# %% [markdown]
# ### 2.2.4 Program "Nilai_2611532030"

# %%
# Buat file dengan nama nilai_nim.py
# Buat program untuk nested if
# Nama variabel ditambah 4 digit terakhir nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()
# Program konversi nilai angka menjadi huruf

nilai_2030 = int(input("Inputkan nilai angka = "))

if nilai_2030 >= 81:
    print("A")
elif nilai_2030 >= 70:
    print ("B")
elif nilai_2030 >= 60:
    print("C")
elif nilai_2030 >= 50:
    print("D")
else:
    print("E")

# %% [markdown]
# <div align="center">
# <img src="images/Output Nilai.png" width="500"><br>
# <em>Gambar 2.4 : Output Nilai</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Pengguna menginputkan nilai angka bulat yang disimpan ke dalam variabel `nilai_2030`.
# 2. Rentang nilai dievaluasi secara hirarkis dari interval tertinggi (>= 81) hingga terkecil (>= 50).
# 3. Jika tidak ada rentang yang dipenuhi (nilai < 50), program otomatis mengeksekusi blok `else` dan mencetak huruf "E".

# %% [markdown]
# ### 2.2.5 Program "Multi_if1_2611532030"

# %%
# Buat file dengan nama multi_if1_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit terakhir nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

umur_2030 = int(input("Input umur anda: "))
sim_2030 = input("Apakah Anda Sudah Punya Sim C (y/t): ")[0]

if umur_2030 >= 17 and sim_2030 == 'y':
    print("Anda sudah dewasa dan boleh bawa motor")

if umur_2030 >= 17 and sim_2030 != 'y':
    print("Anda sudah dewasa tetapi tidak boleh bawa motor")

if umur_2030 < 17 and sim_2030 == 'y':
    print("Anda belum cukup umur punya SIM")

if umur_2030 < 17 and sim_2030 != 'y':
    print("Anda belum cukup umur bawa motor")

# %% [markdown]
# <div align="center">
# <img src="images/Output Multi_if1.png" width="500"><br>
# <em>Gambar 2.5 : Output Multi_if1</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Input dikumpulkan untuk variabel `umur_2030` dan `sim_2030`.
# 2. Berbeda dengan `if-elif-else`, setiap baris `if` bertindak secara mandiri dan selalu dievaluasi oleh interpreter Python tanpa memedulikan hasil pengujian `if` sebelumnya.

# %% [markdown]
# ### 2.2.6 Program "Multi_if2_2611532030"

# %%
# Buat file dengan nama multi_if2_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit terakhir nim terakhir contoh: total_belanja_1234
# Program ini menggunakan fungsi input()
# Program Menghitung Diskon Belanja

# Input dari user
total_belanja_2030 = float(input("Masukkan total belanja (Rp): "))

#Input status member (mengecek apakah user mengetik 'y' atau 'ya')
input_member_2030 = input("Apakah anda member? (y/t): ").strip().lower()
is_member_2030 = input_member_2030 in ["y", "ya"]

# Input status kode promo (mengecek apakah user mengetik 'ya' atau 'ya')
input_promo_2030 = input("Apakah kode promo valid? (y/t): ").strip().lower()
kode_promo_valid_2030 = input_promo_2030 in ["y", "ya"]

total_diskon_persen_2030 = 0

# Multi-IF terpisah: Setiap kondisi diperiksa secara independen
# Diskon bisa ditumpuk (akumulasi) jika memenuhi beberapa syarat sekaligus

if total_belanja_2030 > 1000000:
    total_diskon_persen_2030 += 10  # Diskon belanja besar

if is_member_2030:
    total_diskon_persen_2030 += 5   # Diskon member

if kode_promo_valid_2030:
    total_diskon_persen_2030 += 15  # Diskon voucher

# Menghitung nominal diskon dan total bayar
nominal_diskon_2030 = total_belanja_2030 * (total_diskon_persen_2030 / 100)
total_bayar_2030 = total_belanja_2030 - nominal_diskon_2030

# Output hasil
print("\n--- Rincian Pembayaran ---")
print(f"Total Diskon    : {total_diskon_persen_2030}% (p {nominal_diskon_2030:,.0f})")
print(f"Total Bayar     : Rp {total_bayar_2030:,.0f}")

print(f"Total diskon yang anda dapatkan: {total_diskon_persen_2030}%")
# Output: Total diskon yang anda dapatlkan: 30% jika belanja > 1 juta, member, dan kode promo valid

# %% [markdown]
# <div align="center">
# <img src="images/Output Multi_if2.png" width="500"><br>
# <em>Gambar 2.6 : Output Multi_if2</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Program mengumpulkan total belanja, status keanggotaan member, dan status kode promo. Metode `.strip().lower()` digunakan untuk pembersihan teks agar tidak sensitif huruf besar/kecil.
# 2. Setiap pengondisian `if` terpisah menambahkan persentase diskon secara kumulatif ke dalam variabel `total_diskon_persen_2030`.
# 3. Total pembayaran dihitung secara matematis dengan mengurangi total belanja dengan nominal diskon yang diperoleh.

# %% [markdown]
# ### 2.2.7 Program "Match_case_2611532030"

# %%
# Buat file dengan nama match_case1_nim.py
# Buat program untuk match case
# Nama variabel ditambah 4 digit terakhir nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()
# Program konversi angka menjadi nama bulan

bulan_2030 = int(input("Masukkan angka bulan (1 - 12): "))

match bulan_2030:
    case 1:
        print("Januari")
    case 2:
        print("Februari")
    case 3:
        print("Maret")
    case 4:
        print("April")
    case 5:
        print("Mei")
    case 6:
        print("Juni")
    case 7:
        print("Juli")
    case 8:
        print("Agustus")
    case 9:
        print("September")
    case 10:
        print("Oktober")
    case 11:
        print("November")
    case 12:
        print("Desember")

# %% [markdown]
# <div align="center">
# <img src="images/Output Match_case.png" width="500"><br>
# <em>Gambar 2.7 : Output Match_case</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Nilai masukan dikonversi menjadi `int` dan disimpan pada variabel `bulan_2030`.
# 2. Pernyataan `match` mencocokkan nilai variabel dengan tiap-tiap entri `case`.
# 3. Jika nilai variabel bernilai sama dengan salah satu nilai konstanta pada `case`, blok kode di dalamnya langsung dieksekusi tanpa perlu pengujian operator logika.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# Studi Kasus: Sistem Loket Terpadu & Audit Transaksi Ekspedisi Wahana
# Sebuah wahana rekreasi petualangan membutuhkan sistem loket berbasis konsol untuk menentukan jenis wahana, memverifikasi kelaikan pengunjung dengan kondisi majemuk (logical operators), menghitung diskon akumulatif menggunakan multi-if terpisah, serta mencetak audit status operasional.
# Catatan Materi: Seluruh alur program disusun murni menggunakan 4 pilar percabangan yang diajarkan pada modul Pekan 4: (1) if tunggal, (2) if-else, (3) if-elif-else dengan operator logika (and, or, !=), (4) Multi-if terpisah untuk diskon akumulasi, dan (5) match-case (1 s.d. 5 beserta case _). Tidak ada nested-if (if di dalam if).

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "tugas4_2611532030.py"

# %%
# Nama File : tugas4_2611532030.py
# Nama/NIM  : Maharaja Korga / 2611532030
# Tugas 4   : Struktur Percabangan pada Python (if, if-else, if-elif-else, multi-if, match-case)

import sys

print("=== SISTEM LOKET ALPRO ADVENTURE PARK ===")

# 1. Input Data Pengunjung & String Handling
nama_2030 = input("Masukkan Nama Pengunjung          : ")
umur_2030 = int(input("Input umur anda                  : "))

input_sim_2030 = input("Apakah Anda Sudah Punya SIM C (y/t): ").strip().lower()
sim_2030 = input_sim_2030[0] if input_sim_2030 else 't'

# 2. Pemilihan Wahana Menggunakan match-case
print("\nPilihan Paket Wahana (1-5):")
print("  1. Safari Rimba         (Rp 50,000)")
print("  2. Arung Jeram          (Rp 75,000)")
print("  3. Motor ATV Ekstrim    (Rp 120,000)")
print("  4. Roller Coaster Kilat (Rp 100,000)")
print("  5. All-Access VIP       (Rp 220,000)")

paket_2030 = int(input("Masukkan nomor paket (1-5)      : "))

match paket_2030:
    case 1:
        nama_paket_2030 = "Wahana Safari Rimba"
        harga_satuan_2030 = 50000
    case 2:
        nama_paket_2030 = "Wahana Arung Jeram"
        harga_satuan_2030 = 75000
    case 3:
        nama_paket_2030 = "Wahana Motor ATV Ekstrim"
        harga_satuan_2030 = 120000
    case 4:
        nama_paket_2030 = "Wahana Roller Coaster Kilat"
        harga_satuan_2030 = 100000
    case 5:
        nama_paket_2030 = "Wahana All-Access VIP"
        harga_satuan_2030 = 220000
    case _:
        print("\nPaket wahana tidak valid!")
        sys.exit()

jumlah_tiket_2030 = int(input("Masukkan jumlah tiket            : "))

# Validation if-tunggal untuk jumlah tiket
if jumlah_tiket_2030 <= 0:
    print("\nPeringatan: Kuota tiket tidak valid!")
    sys.exit()

input_member_2030 = input("Apakah Anda member? (y/t)        : ").strip().lower()
input_promo_2030 = input("Apakah kode promo valid? (y/t)   : ").strip().lower()

# 3. Validasi Izin Kendali Wahana Menggunakan if-elif-else dan Operator Logika
print("\n--- KELAYAKAN PENGENDARA WAHANA ---")
if paket_2030 == 3:
    if umur_2030 >= 17 and sim_2030 == 'y':
        print("Status Akses: Anda sudah dewasa dan boleh mengendarai ATV sendiri.")
    elif umur_2030 >= 17 and sim_2030 != 'y':
        print("Status Akses: Anda sudah dewasa tetapi tidak boleh bawa motor ATV (wajib didampingi instruktur).")
    elif umur_2030 < 17 and sim_2030 == 'y':
        print("Status Akses: Identitas tidak valid: Belum cukup umur memiliki SIM.")
    else:
        print("Status Akses: Anda belum cukup umur dan tidak boleh bawa motor ATV.")
else:
    if umur_2030 >= 10:
        print("Status Akses: Pengunjung memenuhi kriteria usia minimal untuk wahana ini.")
    else:
        print("Status Akses: Pengunjung belum cukup umur (wajib didampingi orang tua).")

# 4. Akumulasi Diskon Bertingkat Menggunakan Multi-IF Terpisah
subtotal_2030 = harga_satuan_2030 * jumlah_tiket_2030
total_diskon_persen_2030 = 0

if subtotal_2030 >= 200000:
    total_diskon_persen_2030 += 10

if input_member_2030 in ['y', 'ya']:
    total_diskon_persen_2030 += 5

if input_promo_2030 in ['y', 'ya']:
    total_diskon_persen_2030 += 15

if jumlah_tiket_2030 >= 5:
    total_diskon_persen_2030 += 5

nominal_diskon_2030 = subtotal_2030 * (total_diskon_persen_2030 / 100)
total_bayar_2030 = subtotal_2030 - nominal_diskon_2030

# 5. Evaluasi Kelulusan Audit Menggunakan if-else & Print Output
print("\n--- Rincian Pembayaran ---")
print(f"Subtotal Belanja : Rp {subtotal_2030:,.0f}")
print(f"Total Diskon     : {total_diskon_persen_2030}% (Rp {nominal_diskon_2030:,.0f})")
print(f"Total Bayar      : Rp {total_bayar_2030:,.0f}")

if total_bayar_2030 > 300000:
    print("Catatan Layanan  : Selamat! Anda berhak mendapatkan Souvenir Gratis.")
else:
    print("Catatan Layanan  : Terima kasih telah berkunjung.")

print("Program Selesai")

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/Output Tugas Praktikum.png" width="500"><br>
# <em>Gambar 2.8 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan :**
# Program `tugas4_2611532030.py` disusun untuk menyimulasikan sistem loket terpadu pada Alpro Adventure Park dengan mengimplementasikan 4 pilar percabangan serta prinsip validasi input sebagai berikut:
#
# 1. **Input Data & Pembersihan String**:
#    Program mengumpulkan data pengguna seperti nama (`nama_2030`), umur (`umur_2030`), kepemilikan SIM (`sim_2030`), pilihan paket, jumlah tiket, serta status member dan kode promo. Metode `.strip().lower()` digunakan untuk memastikan masukan huruf kapital/kecil tidak memengaruhi logika pemeriksaan.
#
# 2. **Pemilihan Wahana Menggunakan `match-case`**:
#    Struktur `match-case` memetakan angka pilihan paket (1 sampai 5) ke dalam nama wahana dan harga satuannya. Jika pengguna memasukkan nomor di luar 1–5, jalur `case _` (default) akan mengeksekusi pesan kesalahan *"Paket wahana tidak valid!"* dan menghentikan program secara aman.
#
# 3. **Validasi Kuota Tiket Menggunakan `if` Tunggal**:
#    Pernyataan `if jumlah_tiket_2030 <= 0` memvalidasi input agar jumlah tiket harus bernilai positif. Jika tidak valid, program menampilkan peringatan dan langsung menghentikan proses transaksi.
#
# 4. **Validasi Kelaikan Menggunakan `if-elif-else` dan Operator Logika**:
#    - Untuk Paket 3 (*Motor ATV Ekstrim*), program mengevaluasi 4 kondisi saling lepas (*mutually exclusive*) menggabungkan batas usia (>= 17) dan kepemilikan SIM C (`'y'`) menggunakan operator logika `and` dan `!=`.
#    - Untuk paket selain Paket 3, digunakan pengondisian `if-else` sederhana untuk memeriksa kelaikan usia minimal 10 tahun.
#
# 5. **Akumulasi Diskon Menggunakan `Multi-IF` Terpisah**:
#    Rangkaian pernyataan `if` independen (bukan `elif`) digunakan untuk menghitung total persentase diskon. Karena setiap kondisi diperiksa secara mandiri, diskon dapat diakumulasikan (ditumpuk) jika memenuhi beberapa syarat sekaligus:
#    - Diskon Belanja Besar (subtotal >= Rp 200.000) = +10%
#    - Diskon Member (`is_member` = 'y'/'ya') = +5%
#    - Diskon Kode Promo (`kode_promo` = 'y'/'ya') = +15%
#    - Diskon Rombongan (jumlah tiket >= 5) = +5%
#
# 6. **Evaluasi Bonus & Audit Menggunakan `if-else`**:
#    Setelah menghitung `nominal_diskon_2030` dan `total_bayar_2030`, program mengevaluasi nilai transaksi menggunakan `if-else`:
#    - Jika `total_bayar_2030 > 300000`, pengguna mendapatkan pesan bonus *"Selamat! Anda berhak mendapatkan Souvenir Gratis."*
#    - Jika kurang dari atau sama dengan Rp 300.000, program mencetak *"Terima kasih telah berkunjung."*
#    Seluruh output rincian biaya ditampilkan menggunakan format *f-string* angka ribuan desimal (`:,.0f`).

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum mengenai struktur percabangan pada Python yang telah dilakukan, dapat disimpulkan bahwa:
#
# 1. Pengambilan Keputusan Otomatis: Struktur percabangan (`if`, `if-else`, `if-elif-else`, `multi-if`, dan `match-case` memungkinkan program mengambil keputusan logis secara fleksibel berdasarkan evaluasi kondisi boolean dari variabel masukan.
#
# 2. Perbedaan Karakteristik:
#
#     - Structure `if-elif-else` bekerja secara mutually exclusive (saling lepas), di mana hanya satu blok kondisi bernilai `True` pertama yang akan dieksekusi.
#
#     - Structure `Multi-IF` bekerja secara independen, sehingga beberapa syarat yang terpenuhi dapat mengeksekusi beberapa blok kode sekaligus (seperti pada akumulasi diskon).
#
#     - Structure `match-case` menyajikan alternatif sintaks yang lebih bersih, rapi, dan efisien dalam melakukan pemetaan nilai diskrit dibanding penggunaan banyak `elif`.
#
# 3. Penggunaan Variabel & NIM: Penerapan identifikasi variabel berakhiran 4 digit NIM (`_2030`) mempermudah pelacakan alur variabel serta pemenuhan standar penulisan kode praktikum secara konsisten

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Rossant, C., IPython Interactive Computing and Visualization Cookbook, 2nd ed. Birmingham: Packt Publishing, 2018.
#
# [2] Van Rossum, G., Drake, F. L., The Python Language Reference Manual, Python Software Foundation, 2023. [Online]. Tersedia: https://docs.python.org/3/reference/ [Diakses tanggal: 25 September 2026].
#
# [3] Severance, C., Python for Everybody: Exploring Data in Python 3, CreateSpace Independent Publishing Platform, 2016, Hal. 33-45.
